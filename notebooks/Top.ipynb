# %% [markdown]
# # 理論・法則の教科書（説明は将来のバージョンの話です）
#
# - 20歳ぐらいなら誰でもわかる言葉とシミュレーションで体験します
#     - 学ぶことは楽しいですが難しい
#         - 当サイトは専門家でなくても問題ありません
#             - 全部の問題を解くには専門的な知識が必要です
# - 基礎ができればいろいろできます
#     - 国語を知らなきゃ本も読めない
#         - 理論を知らなきゃ世界が読めない
# - ※ 天才の方はこのドキュメントを参考程度でお願いします
# - ※ お年寄りも無視でお願いします
# - ※ 超感覚派は感性の方が重要かもしれません。限界を感じたらこちらへ
# - ※ 全体像を見る目的のため、メモ部分はかなりざっくりです

# %% [markdown]
# # 理論1層 熱による進化 [リンク](Theory1.ipynb)
#
# - 最適化理論の説明をします
#     - なぜか: 成長が重要であり、理論は信じられる特性を持つからです
#         - 最適化(数学)～進化(世界)～教育(社会)～成長(個人)のような流れです
#     - なぜ、シミュレーションなのでしょうか、体験という情報が付与されます。理論だけでは机上の空論と呼ばれるでしょう
#         - さらに、学んだあと本当の経験が必要です

# %% [markdown]
# # 人と社会 1層 (メモレベル：未実装：理系の戯言です)
#
# シミュレーションより、リアル体験の方や動画が成長すると予想<br/>
# 詳細まで記載しないのは汎用的・確定的情報はないため
#
# - 理論だけだと偏りそうなので、暫定で配置
# - 人の万能性、かつ、非常に高い能力により人が重要であるため
#
# ### 調和
#
# - 色々な要素のバランスが取れるのが好ましい
#     - このサイトで推す「理論・法則」、「人と社会」、「遊びと創造」以外のことも大事です
#     - 実態に基づいて改善する
# - 過剰は構造の問題と予想
# - ぴったり合うがある
#     - 音楽の和音
#     - 波の共鳴 (破壊)
#     - 物の共振 (破壊)
# - 一人でバランスを取る必要はない
# - 山あり谷あり
# - 不気味の谷
#
# ### 心
#
# - 変えられないことで悩まない
#     - 根源は変えにくい
#         - 幼少期の体験は根源となると予想
#         - コストパフォーマンスも考慮
# - 感情は評価
#     - 面白いの感情は理論や法則に反応する価値観と予想します
#     - 幸せ/嬉しいは個人/社会と予想します
#         - 幸せは眠い時に寝る、おなかすいたら美味しいものを食べると予想します
#         - 嬉しいは人がしてくれたことに関する感謝の心と予想します
#     - 楽しいは遊び・創造と予想します
#     - 始まりは感情に近いものが遺伝子的に組み込まれる
#         - 心理学の情動
#     - 知識・経験により行動決定の最終評価は変わります
# - 心もバランス
#     - 楽しいも疲れる
#         - ストレス
# - 日本人が心を大事にするのは人の根源だからと予想します
#     - 日本のホラーはお化け
#         - 恨みに着目
#     - 海外は13日の金曜日?、テロリスト
#         - 具体的殺害
#
# ### チームでの創造
#
# - 結果
#     - 複雑な問題では結果が最重要軸である
#         - お金も組織の共通の評価軸になる
#             - 最重要なだけで現代の価値観は多様です
#     - 計画は結果確認に必要
#         - 想像に対する結果や前回と今回の比較ができない
#     - 過程の評価は成長を目指すという意味
#         - 正確な分析や結果との比較が重要

# %% [markdown]
# # 遊びと創造1 (メモレベル：未実装)
#
# 自分だけのオンリーワンでみんなを元気にする ※ 理論系や人間系の要素が0に近い場合
#
# - この分類は雑に見えますがGANのGeneratorから想起しました。
# - 体験と遊びの違い
#     - 体験は受動、遊びは能動
#     - 体験は価値がある、遊びは無駄という概念
#         - 創造という側面では遊びの方がいいと思います
#     - 体験はたくさん、遊びは少し
# - 学ぶには実際やること
#     - 製作等
#     - スポーツ等
#     - 絵画等
#     - ゲーム
#     - 動画は他の人との関係
#
# ### 行動できることは一つ
#
# - 個人善と呼ぶ
#     - 社会はあらゆる経験で最善手を行うことで最適化されると予想
#         - あらゆる経験とは個人経験の集合
#         - 最善手とは個人善の集合
#         - ゲームでは噛み合うがあると書きましたが、待つのも最善手になりうる
#     - ウン十億人を3軸で押し込むのは無理がある
#     - 評価基準は人によって違う、問題の解き方も人によって違う
#     - 赤という色覚も人によってわずかに違うらしい
#
# ### 創造の総合性
#
# - 感覚、実行計画、実行、結果確認
#     - 感覚とはセンサー・計測入力
#     - 実行計画とは思考、判断
#     - 実行とは手順の創造通りに行うこと、制御、創造
# - 強い唯一性
#     - 他の人が同じ体験をしにくい
# - 進化ループ
#     - PDCAという手法がある
#
# ### 革新
#
# 成長しないのは近くにベターがない
#
# - 規則の外を探す
# - 旅に出る
# - 独創
#
# ### コスパ
#
# - 数値目標に対する、重要資源の寄与率を高くする
#     - 資源が有限なら最重要
# - 理論側に分類する？

# %% [markdown]
# # その他 (メモレベル：未実装)
#
# - 偏りは産まれてしまう
# - 空間の広さだけ意味がありうる
#     - 主成分分析より
#
# ## 上位20%の人で80%の成果 20:60:20
#
# - 特定の指標に注目している
# - 上位が在れば下位がある
# - 他人を成長させる人
#     - あくまで計測
# - 常に成り立つ法則ではない
#     - 2軸に適用した場合の根拠の低さ
# - パレートの法則、22%と78%
#     - 役割が同じ人が多いから、バランスが悪くなる説がある
#     - 役割を決めるのはちょっと
#
# ## その他
#
# - ポジティブな考えを経験が否定する場合がある
# - 世の中の当たり前が増えることが相対的な不幸の発生率と評価を変える
# - 失敗してもフィードバック
#
# [未整理メモ](notitle.ipynb)
