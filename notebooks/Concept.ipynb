# %% [markdown]
# ### コンセプト
#
# - 当たり前の人も多いでしょうが、価値があるかはこれから調査します
# - 諦めない構造
#     - 詳細は人それぞれ
# - 現状では僕の予想を書いてます。これ最善ですかと聞かれましたが、ご容赦ください。最適化理論は最適に向かうだけですので、このサイトも進化するように作る予定です
#     - 僕の時代の教科書自体が最善にみえません
# - 情報科学的哲学(シミュレーションによる哲学)を推奨するサイトであると言えます（人工知能・宇宙等の学際的テーマについて）
#     - 新領域の発明・発見に有効
#         - なぜ哲学か
#             - 強い意味の哲学的記憶により、抽象的な高速思考ができる
#                 - 情報科学で大事な考え方です
#                 - 頭のメモリを削除
#         - ニュートン力学は難しい問題で高速、量子力学は低速です
#            - しかし、量子力学でニュートン力学に意味を与えます
#     - 複雑な話題(学際的)に有効
#         - 応用数学であり、文科系向けの数学であると言えます
#         - 例えば、技術倫理考えるならその技術について知っておく必要がある
#             - 結果から語りやすいですが、お花畑扱いされてしまいます
#     - 情報科学的には概念の重複を減らしますが、まとめるのが必ずしも正しいわけではない
#         - オブジェクト指向やフレームワーク等はヒントとなりうる
#             - 情報科学の一般的対象は人間的な複雑なものであるため、上記はシンプルな概念ではありません
#                 - 専門性が必要です
#         - 今は、「揺らす」だけの　「発明に良さそうな」、「文化的により良さそうな」概念でしかありません
#             - 検証や追試、僕の理論の完成は少々お待ちください
#     - 詳細まで詰めると全方面への喧嘩です。答えはいずこ
#         - コスパはあるでしょう
#     - 僕のアイディアは知り合いの多さに依存します
#         - いない人は平均的自殺
#         - いる人は？
#         - コスパ　結局コスパが大事なだけ
#         - 幸せが欲しいけど、僕には答えが無いのね
#
# ### 詳細をご希望の方はご質問ください
#
# - 簡単な質問は無料で受け付けます
#     - twitter の DM を頂けたらと思います
#         - 会話した内容はこのプロジェクトに反映される可能性があります
# - 複雑な質問や社会的影響の多い質問は有料となる可能性があります
#     - 会話した内容は同様にこのプロジェクトに反映される可能性があります
#     - 極秘の話題については、僕がその組織への所属レベルで検討します
