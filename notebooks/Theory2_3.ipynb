# %% [markdown]
# ## 汎用（メモレベル）
#
# - シミュレーションはありません
#
# ### 算数（数学）
#
# 整数の特性は頻繁に登場します
#
# - 量子力学は積分は使わず、合計だけが行われています
#     - 合計だけとは積分に対応してであり、数式は色々あります
#     - 合計とはExcelとかプログラミングのsum
#     - 工学的な積分は近似値と言えます。精度さえ取れれば、近似でも誤り訂正（のようなもの）をすれば問題ありません
# - [数学メモ1](MathMemo1.ipynb)
#
# #### 数学の各分野
#
# - 統計
#     - 大量の結果を分析する
#         - 結果は人間の考え方を含む場合が多い
#             - 評価～行動など、1層の遊びと創造を参照
#         - 注目した対象のみ
#     - 平均的な物を強く特徴付ける
#         - 例外ははずれている(ことがわかる)
#
# ### フラクタルと再帰
#
# - 量子化現象は量子力学だけではなく、人間の目で見える物質のようにフラクタルに現れます
#     - 大抵別物ですが、特性はある(数えられる)
# - [動的計画法](https://ja.wikipedia.org/wiki/%E5%8B%95%E7%9A%84%E8%A8%88%E7%94%BB%E6%B3%95)
#     - 分割統治と一時記憶
#         - 一時記憶するには再帰が必要
#             - 同じ構造だから再帰となり、同じ構造は同じ結果がでやすく一時記憶の効率があがるため
#
# ### 脳
#
# - 人は脳と体と道具でかなりの問題を解決してきました
# - 再帰的に全ての問題を解けると予想します
#     - 資源と時間がある限り
#
# #### 僕の中での人間の思考の概念(脳科学はしらない)
#
# 下記は左脳的かもしれません
#
# - 入力（五感） ⇒ 記憶
#     - 特徴(GPUでのDNN?) ⇒ 記憶
#         - 感情(評価1) ⇒ 記憶
#             - 想像（人によるが、感情をくみ取ったり、計算したり） ⇒ 記憶
#             - 創造(デザイナー的) ⇒ 記憶
#             - 記憶（記号的：いろいろな情報が混ざる？）
#                 - 論理判断(論理(CPU:探索:幅優先、深さ優先、組み合わせ)、評価2) ⇒ 記憶
#                     - 軸を中心に考える(将棋なら、1手目を飛車を軸に考えるみたいな)
#                 - 想像(シミュレーション：かなり色々、評価3：レア度や経験価値が高いと判断すると閃き) ⇒ 記憶
#                 - 入力へ(1刺激で数回まで)
#                 - 創造(理論的デザイン) ⇒ 記憶
#     - 運動系特徴(最終性能重視)
#         - 行動(制御) ⇒ 記憶
#             - 入力へ？(1刺激で数回まで)
#         - 創造(画家的) ⇒ 記憶
#
# ### 説明
#
# - 脳における特徴
#     - 2層理論　ニューラルネットワーク参照
# - 感情は当サイトの1層を参照
# - 論理判断も並列で行っている
#     - 直列の度合いは高い
#
# ### プログラミング
#
# - チューリング完全である限り、あらゆるものが作れると予想します
#     - 簡単な機械（仕組み）でできる
#     - cpuとメモリがたくさん必要
#     - SKIコンビネータという概念もあります
# - 最小限の資源で表現できるモデルが望まれます
#     - 物理学の真空エネルギーが有力
#     - [アメーバの一種「モジホコリ」を使って数学の難問「巡回セールスマン問題」を解くことができると判明](https://gigazine.net/news/20181225-amoeba-solves-hard-math-problem/)
#         - イメージです
#
# ### 矛盾や無空間？
#
# - ありえないということは、あらゆる状況で生まれます
# - タブーサーチという最適化理論の性能が低いと予想
#     - 失敗経験と同じことをしないようなアルゴリズム
#         - 限定的な即死条件には重要
#         - 人間の他の知性と組み合わせて性能は悪いとは断定できません
#     - エキスパートシステムにも通じる
#         - 記憶だけで全て対応する
#
# ## 意外性のある理論を紹介？したので、よくあるアルゴリズムを紹介
#
# - 二分探索
#     - ビッグアンドローで100個の数値の中から答えを見つける：100->50->25->12->6->3->1
# - シンプレックスタブロー
#     - 答えの1次の数式群がある前提で多角形の表面を最短に（直線の組み合わせで）高い方向へ移動するイメージ
# - 回帰分析
