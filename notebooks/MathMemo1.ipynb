# %% [markdown]
# ### メモ
#
# - 情報科学的な学問としての数学
#     - 無限を許可しない
#     - scheme (lisp)が近い
#     - 言語（その数学）の最適を評価できない
#         - 宇宙論が目的かつ情報科学的に中途半端
#             - 理論物理で良さそう
#             - 数学の情報科学的コンパイラ(エラーチェック)は何となく欲しいかも
#                 - coq?
#                     - coq の探索機能：性能はいかほど？
#                     - さすがに勉強できてません
#         - プログラミング自体は
#             - 目的に応じて進化し続ける
#                 - cpu や network等の具体にひきづられる
#                     - 場合により社会?にも引きづられる
# - 有理数は遅延評価がなければ、現実(量子世界)では限定的にしか使えないように見えますが、工学的には使えます
#     - 計算の止まらない有理数はありえませんが、Haskellで採用された遅延評価であり得る可能性も考えられます
# - 複雑になると数学により数学が生まれるので体験のハードルが上がりかなり難しい
#     - 超強力な暗算必須に見えます
# - 算数のなんとなくな解釈は動物でもできる
#     - 算数と定義できるレベルの公式の始まりはいつか
#         - 定義（共通認識）ができれば一瞬で公式ができそうではある
#     - 算数以降のある程度もパターンで発見は説明できそう
#         - 数学的抽象とはどのような能力か
# - 非数学者向け
#     - 数学は人間の思想を重視した、矛盾を含む宇宙より正しい？：宇宙の空間が広くなったら正しくなる？
#     - 自分の好きなものを信じましょう
#     - NやZ自体が無限だった、無限になる一歩手前すら定義できない
#         - n = 1　ｎ以下の自然数の個数は有限個である
#         - n = k のとき　「ｋ以下の自然数の個数が有限個であると仮定する」
#             - この仮定は一般的ではない
#                 - 非停止状態の場合は適用外
#                 - こんな説明書きたくない
#         - n = k + 1 とき　高々１個増えただけなのでｋ＋１以下の自然数の個数は有限個である
#         - 無限に近い数字は取り扱わないので問題になりにくい
#     - 収束するというのは宇宙より正しい
#         - 発散は現象であるが、特性は抽象的
#         - 数学者としても、特性以外で認識すると新しい発想を阻害しないだろうか
#             - 発散は深さ優先に近い？
#             - 特性は幅優先に近い？
#                 - 他で書いたが将棋的な読みが必要？
#     - 数学の新演算子の優先順位を定義できているのかよくわからない（少なくとも説明する資料は少ない）
#         - 新記号・表記が門外漢にわからない
#     - githubの方がオープンで論文より価値がありそうだけど、高度な話題は論文にしたい？スパコン系は追試できる人がほぼ？いません
#         - ＡＩはデータすらない
#             - データが無い方が汎用性のある議論はできるが議論の収束は？
